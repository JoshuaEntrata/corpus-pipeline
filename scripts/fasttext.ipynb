# %%
import fasttext

# %%
ft = fasttext.load_model("../models/lid.176.ftz")

# %%
ft.f.predict("This is a test sentence.", 3, 0.0, "strict")
# Out:
# [(0.9501287937164307, '__label__en'),
#  (0.0037755602970719337, '__label__es'),
#  (0.003347062272951007, '__label__pt')]

# %%
# Tagalog

ft.f.predict("Ginagamit ng doktor ang AI chatbot para tulungan ang pasyente sa sintomas bago konsultasyon.", 3, 0.0, "strict")
# Out:
# [(0.9551992416381836, '__label__tl'),
#  (0.01198096014559269, '__label__ceb'),
#  (0.008154409006237984, '__label__sc')]

# %%
# Cebuano

ft.f.predict("Ang ospital naggamit ug machine learning aron matagna ang risgo sa sakit sa pasyente.", 3, 0.0, "strict")
# Out:
# [(0.8168579936027527, '__label__ceb'),
#  (0.1535198986530304, '__label__tl'),
#  (0.013723020441830158, '__label__ia')]

# %%
# Ilocano

ft.f.predict("Ti klinika ket agar-aramat iti algorithm tapno maibaga no kasapulan ti pasiente ti follow-up.", 3, 0.0, "strict")
# Out:
# [(0.6250895261764526, '__label__ilo'),
#  (0.03976002335548401, '__label__tl'),
#  (0.029469210654497147, '__label__pt')]

# %%
# Hiligaynon

ft.f.predict("Ang doktor nagagamit sang AI para magbulig basa sang resulta sang laboratoryo.", 3, 0.0, "strict")
# Out:
# [(0.19832146167755127, '__label__tl'),
#  (0.08517614006996155, '__label__la'),
#  (0.07778237760066986, '__label__sq')]
